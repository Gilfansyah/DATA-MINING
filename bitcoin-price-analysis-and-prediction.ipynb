# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/bitcoin-btc-usd-stock-dataset/BTC-USD_stock_data.csv

# %%
file_path = '/kaggle/input/bitcoin-btc-usd-stock-dataset/BTC-USD_stock_data.csv'
df = pd.read_csv(file_path)
df['auto_pct'] = df['Adj Close'].pct_change() * 100
display(df)
# Out:
#             Date          Open          High           Low         Close  \
# 0     2017-01-01    963.658020   1003.080017    958.698975    998.325012
# 1     2017-01-02    998.617004   1031.390015    996.702026   1021.750000
# 2     2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 3     2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 4     2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...          ...           ...           ...           ...           ...
# 2831  2024-10-02  60836.324219  62357.687500  59996.949219  60632.785156
# 2832  2024-10-03  60632.484375  61469.039062  59878.804688  60759.402344
# 2833  2024-10-04  60754.625000  62465.992188  60459.941406  62067.476562
# 2834  2024-10-05  62067.609375  62371.023438  61689.582031  62089.949219
# 2835  2024-10-06  62084.988281  62959.570312  61833.148438  62818.953125
#
#          Adj Close       Volume   auto_pct
# 0       998.325012    147775008        NaN
# ...

# %%
min_date = min(df['Date'])
max_date = max(df['Date'])

print(f'Min Date: {min_date}')
print(f'Max Date: {max_date}')
# Out:
# Min Date: 2017-01-01
# Max Date: 2024-10-06

# %%
plt.figure(figsize=(10, 5))
plt.plot(df['Date'], df['High'], label='High', color='blue')
plt.plot(df['Date'], df['Low'], label='Low', color='orange')
plt.title('High and Low Values of BTC-USD Price')
plt.xlabel('Date')
plt.ylabel('Price (USD)')
plt.xticks([]) 
plt.legend()
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.bar(df['Date'], df['auto_pct'], color='blue')
plt.xlabel('Date')
plt.ylabel('Percentage Change (%)')
plt.title('Daily Percentage Change in BTC-USD Price')
plt.xticks([])  # Rotate date labels for better readability
plt.tight_layout()

plt.show()

# %% [markdown]
# The Dark Day on BITCOIN PRICE

# %%
df['auto_pct'].describe()
# Out:
# count    2835.000000
# mean        0.217958
# std         3.775951
# min       -37.169539
# 25%        -1.386785
# 50%         0.136582
# 75%         1.799648
# max        25.247169
# Name: auto_pct, dtype: float64

# %%
plt.figure(figsize=(5,5))
plt.boxplot(df['auto_pct'].dropna(), vert=True)
plt.title('Box Plot of Daily Percentage Change in BTC-USD Price')
plt.ylabel('Percentage Change (%)')
plt.xlabel('BTC-USD')

plt.show()
